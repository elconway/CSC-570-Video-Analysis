# %%
import pandas as pd

# %%
emotiv = pd.read_csv('datasets/HeadsetData2023-05-03_23-33-26_EPOCX_182325_2023.05.03T23.33.29.07.00.md.pm.bp.csv')
eye = pd.read_csv('datasets/EyeTracking2023-05-03_23-33-26.csv')

# %%
eye['Timestamp'] = (eye['Timestamp']/1000).astype(int)
emotiv['Timestamp'] = emotiv['Timestamp'].astype(int)

# %%
eye
# Out:
#       Timestamp           X           Y
# 0    1683182000  500.274372  499.901398
# 1    1683182000  503.078175  499.155832
# 2    1683182000  511.900882  497.546378
# 3    1683182001  529.960583  496.267070
# 4    1683182001  555.597081  496.214530
# ..          ...         ...         ...
# 534  1683182054  941.252831  464.718258
# 535  1683182054  895.084918  531.453396
# 536  1683182054  875.380661  568.613268
# 537  1683182054  827.581388  589.518115
# 538  1683182054  791.305442  625.781705
#
# [539 rows x 3 columns]

# %%
emotiv
# Out:
#       Timestamp  MOT.CounterMems  MOT.InterpolatedMems    MOT.Q0    MOT.Q1  \
# 0    1683182009             28.0                   0.0  0.474835  0.362183
# 1    1683182009             29.0                   0.0  0.474852  0.362183
# 2    1683182009             30.0                   0.0  0.474992  0.361938
# 3    1683182009             31.0                   0.0  0.474980  0.362122
# 4    1683182009              0.0                   0.0  0.474830  0.361938
# ..          ...              ...                   ...       ...       ...
# 641  1683182029             29.0                   0.0  0.474429  0.364746
# 642  1683182029             30.0                   0.0  0.474574  0.364685
# 643  1683182029             31.0                   0.0  0.474736  0.364685
# 644  1683182029              0.0                   0.0  0.474736  0.364685
# 645  1683182029              1.0                   0.0  0.474689  0.364807
#
# ...

# %%
merged = emotiv.merge(eye, on='Timestamp', how='left')

# %%
merged.to_csv('merged.csv', index='False')
